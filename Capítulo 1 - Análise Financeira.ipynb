# %%
import pandas as pd
import numpy as np
from binstar_client.scripts.cli import binstar_main

# %%
df_credit_risk = pd.read_csv("default of credit card clients (LIMPO).csv")
df_credit_risk.head(10)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      4      4
# 2   3    90000.0    2          2         2   34      4      4      4      4
# 3   4    50000.0    2          2         1   37      4      4      4      4
# 4   4    50000.0    1          2         1   57     -1      4     -1      4
# 5   4    50000.0    1          1         2   37      4      4      4      4
# 6   7   500000.0    1          1         2   29      4      4      4      4
# 7   8   100000.0    2          2         2   23      4     -1     -1      4
# 8   9   140000.0    2          3         1   28      4      4      2      4
# 9  10    20000.0    1          3         2   35     -2     -2     -2     -2
#
#    ...  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0  ...       689         4         4         4         4
# ...

# %%
df_credit_risk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
pay_status = ['PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']
df_credit_risk[pay_status]
# Out:
#        PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6
# 0          2      2     -1     -1     -2     -2
# 1         -1      2      4      4      4      2
# 2          4      4      4      4      4      4
# 3          4      4      4      4      4      4
# 4         -1      4     -1      4      4      4
# ...      ...    ...    ...    ...    ...    ...
# 29995      4      4      4      4      4      4
# 29996     -1     -1     -1     -1      4      4
# 29997      4      3      2     -1      4      4
# 29998      1     -1      4      4      4     -1
# 29999      4      4      4      4      4      4
#
# [30000 rows x 6 columns]

# %%
import matplotlib.pyplot as plt 
import matplotlib as mpl

# %%
_ = plt.hist(df_credit_risk[pay_status[0]], bins=sorted(df_credit_risk[pay_status[0]].unique()))  # aqui adicionamos o número de bins corretos, com isso, não aconteceu agrupamento de dados

# %%
plt.hist(df_credit_risk[pay_status[0]])
# Out:
# (array([ 2759.,  5686.,     0.,  3688.,  2667.,   322., 14850.,     0.,
#             0.,    28.]),
#  array([-2., -1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.,  8.]),
#  <BarContainer object of 10 artists>)

# %%
df_credit_risk[pay_status[3]]
# Out:
# 0       -1
# 1        4
# 2        4
# 3        4
# 4        4
#         ..
# 29995    4
# 29996   -1
# 29997   -1
# 29998    4
# 29999    4
# Name: PAY_4, Length: 30000, dtype: int64

# %%
list_bins = sorted(df_credit_risk[pay_status[0]].unique())
mpl.rcParams['font.size'] = 4
mpl.rcParams['figure.dpi'] = 200
_ = df_credit_risk[pay_status].hist(bins=list_bins, layout=(2, 3))
